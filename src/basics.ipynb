# %%
# %fs ls '/databricks-datasets/'

# %%
# %run ./includes/setup

# %%
print(full_name)

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files = dbutils.fs.ls('databricks-datasets')

j= 1
for file in files:
    print( str(j) + ": " + file.path)
    j+= 1

# %%
display(files)
