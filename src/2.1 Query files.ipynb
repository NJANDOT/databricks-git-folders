# %%
# %run ../../Databricks-Certified-Data-Engineer-Associate/Includes/Copy-Datasets

# %%
# %sql
select * from json.`/Volumes/datademo/default/bookstore_dataset/customers-json/export_*.json`

# %%
# %sql
select * from json.`/Volumes/datademo/default/bookstore_dataset/customers-json/`

# %%
# %sql
select count(*) from json.`/Volumes/datademo/default/bookstore_dataset/customers-json`

# %%
# %sql
select *, input_file_name() source_file from json.`/Volumes/datademo/default/bookstore_dataset/customers-json`;

# %%
# %sql
select * from text.`/Volumes/datademo/default/bookstore_dataset/customers-json`

# %%
# %sql
select * from binaryFile.`/Volumes/datademo/default/bookstore_dataset/customers-json`

# %%
# %sql
select * from csv.`/Volumes/datademo/default/bookstore_dataset/books-csv`

# %%
# %sql
--CREATE TABLE book_csv (
--  book_id STRING,
--  title STRING,
--  author STRING,
--  category STRING,
--  price DOUBLE)
--USING CSV
--OPTIONS (delimiter = ";", header 'true')
--LOCATION "/Volumes/datademo/default/bookstore_dataset/books-csv"; ben non bonhomme, abfss

# %%
# %python
#(spark.read
#        .table("books_csv")
#      .write
#        .mode("append")
#        .format("csv")
#        .option('header', 'true')
#        .option('delimiter', ';')
#        .save(f"{dataset_bookstore}/books-csv"))

# %%
# REFRESH TABLE books_csv when adding new data but spark keeping older data in its cache

# %%
# %sql
CREATE TABLE customers AS
SELECT * from json.`/Volumes/datademo/default/bookstore_dataset/customers-json`;
    
DESCRIBE EXTENDED customers;

# %%
# %sql
CREATE TABLE books_unparsed AS
SELECT * from csv.`/Volumes/datademo/default/bookstore_dataset/books-csv`;

SELECT * FROM books_unparsed;

# %%
# %sql
CREATE TEMPORARY VIEW tw_books_unparsed (book_id STRING, title STRING, author STRING, category STRING, price DOUBLE)
USING CSV
OPTIONS (delimiter = ";", header 'true', path ="/Volumes/datademo/default/bookstore_dataset/books-csv");

CREATE TABLE books as SELECT * FROM tw_books_unparsed;

select * from books;

# %%
# %sql DESCRIBE EXTENDED books;

# %%
 # %sql

 --or...

 SELECT * FROM read_files(
  '/Volumes/datademo/default/bookstore_dataset/books-csv/export_*.csv',
  format => 'csv',
  header => 'true',
  delimiter => ';'
);

# %%
# %sql
CREATE TABLE books_bis
AS SELECT * FROM read_files(
    '/Volumes/datademo/default/bookstore_dataset/books-csv/export_*.csv',
    format => 'csv',
    header => 'true',
    delimiter => ';'
);

DESCRIBE EXTENDED books_bis;
